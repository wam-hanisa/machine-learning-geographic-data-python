# %%
import geopandas as gpd
shapefile = gpd.read_file(
    "chapter_01_data\\les-commerces-par-commune-ou-arrondissement-base-permanente-des-equipements.shp")
print(shapefile)
# Out:
#       departement  departement               libelle_de_  arrondissem  \
# 0         77530.0      77530.0                   Voulton        773.0
# 1         75119.0      75119.0  Paris 19e Arrondissement        751.0
# 2         78335.0      78335.0                     Limay        781.0
# 3         94054.0      94054.0                      Orly        941.0
# 4         77332.0      77332.0               Nantouillet        771.0
# ...           ...          ...                       ...          ...
# 1295      77439.0      77439.0                    Salins        773.0
# 1296      78285.0      78285.0                   Gressey        781.0
# 1297      94002.0      94002.0               Alfortville        941.0
# 1298      77037.0      77037.0               Bois-le-Roi        774.0
# 1299      77110.0      77110.0                    Chenou        774.0
#
#       canton_vill  zone_d_empl unite_urbai  population_  hypermarche  \
# ...

# %%
shapefile.plot()
# Out:
# <Axes: >

# %%
import fiona
fiona.drvsupport.supported_drivers['KML'] = 'rw'

kmlfile = gpd.read_file("chapter_01_data\les-commerces-par-commune-ou-arrondissement-base-permanente-des-equipements.kml")
print(kmlfile)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\l'
# <>:4: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\Aqwam\AppData\Local\Temp\ipykernel_6008\213408767.py:4: SyntaxWarning: invalid escape sequence '\l'
#   kmlfile = gpd.read_file("chapter_01_data\les-commerces-par-commune-ou-arrondissement-base-permanente-des-equipements.kml")
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[5], line 4
#       1 import fiona
#       2 fiona.drvsupport.supported_drivers['KML'] = 'rw'
#       3
# ----> 4 kmlfile = gpd.read_file("chapter_01_data\les-commerces-par-commune-ou-arrondissement-base-permanente-des-equipements.kml")
#       5 print(kmlfile)
#
# File c:\Data\LearnMLAI\machine-learning-geographic-data-python\venv\Lib\site-packages\geopandas\io\file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
# ...

# %%
kmlfile.plot()

# %%
import geopandas as gpd
geojsonfile = gpd.read_file(r"chapter_01_data\festivals-global-festivals-pl.geojson")
print(geojsonfile)
# Out:
#                                    nom_du_festival envergure_territoriale  \
# 0                       Des Planches et des Vaches                    NaN
# 1                       Festival celte en Gevaudan              Régionale
# 2     Festival International de Châteauroux - DARC         Interrégionale
# 3                         Contre-plongées de l'été                    NaN
# 4                        Festival des Filets Bleus                    NaN
# ...                                            ...                    ...
# 7278                                  Zik en ville                    NaN
# 7279                                 Jazz in arles                    NaN
# 7280                               Glisse en Coeur                    NaN
# 7281                                Night'n Bulles                    NaN
# 7282                              Lyon BD festival              Nationale
#
#      region_principale_de_deroulement departement_principal_de_deroulement  \
# ...

# %%
geojsonfile.plot()
# Out:
# <Axes: >

# %%
import rasterio
from rasterio.plot import show
fp = r'ore-kbz-mnt-litto3d-5m.tif'
img = rasterio.open(fp)
show(img)
